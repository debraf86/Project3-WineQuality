# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
wine_df = pd.read_csv('Resources/winequality-red.csv')

# %%
wine_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# wine_df.describe().to_csv(r'Resources/describe_df.csv')

# %%
sns.set()
wine_df.hist(figsize=(15,15), color='firebrick')
plt.xticks(fontsize=12, label='large')
plt.rcParams.update({'font.size':24})
plt.show()
plt.savefig('Resources/wine-hist1.png')

# %% [markdown]
# ## Observation
#
# Difference in the scale of features may negatively impact machine learning algorithms.
#
# The boxplot below also shows the difference in the scale of features.
#
# Normalization is needed to avoid negative impact to the performance of ML algorithms.

# %%
plt.figure(figsize=(15,10))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
sns.boxplot(data=wine_df.drop(columns=['quality']), orient='horizontal', palette='Reds')
plt.savefig('./Resources/wine-boxplot1.png')

# %%
# plt.figure(figsize=(10,10))
# sns.boxplot(data=wine_df.drop(columns=['quality']), orient='horizontal', palette='Reds',showfliers=False)

plt.figure(figsize=(15,10))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
sns.boxplot(data=wine_df.drop(columns=['quality']), orient='horizontal', palette='Reds', showfliers=False)
plt.savefig('./Resources/wine-boxplot-new.png')

# %%
# iterate through each row and normalize between 0 and 1. 
# df2=pd.DataFrame([])
# for i in range(len(wine_df)) : 
#     df2["fixed acidity"] = (wine_df.loc[i, "fixed acidity"] - wine_df["fixed acidity"].min())/ (wine_df["fixed acidity"].max()-wine_df["fixed acidity"].min())
#     df2["volatile acidity"] = (wine_df.loc[i, "volatile acidity"] - wine_df["volatile acidity"].min())/ (wine_df["volatile acidity"].max()-wine_df["volatile acidity"].min())
#     df2[ "sulphates"] = (wine_df.loc[i, "sulphates"] - wine_df["sulphates"].min())/ (wine_df["sulphates"].max()-wine_df["sulphates"].min())
#     df2["density"] = (wine_df.loc[i, "density"] - wine_df["density"].min())/ (wine_df["density"].max()-wine_df["density"].min())
#     df2[ "residual sugar"] = (wine_df.loc[i, "residual sugar"] - wine_df["residual sugar"].min())/ (wine_df["residual sugar"].max()-wine_df["residual sugar"].min())
#     df2[ "free sulfur dioxide"] = (wine_df.loc[i, "free sulfur dioxide"] - wine_df["free sulfur dioxide"].min())/ (wine_df["free sulfur dioxide"].max()-wine_df["free sulfur dioxide"].min())
#     df2[ "total sulfur dioxide"] = (wine_df.loc[i, "total sulfur dioxide"] - wine_df["total sulfur dioxide"].min())/ (wine_df["total sulfur dioxide"].max()-wine_df["total sulfur dioxide"].min())
#     df2[ "pH"] = (wine_df.loc[i, "pH"] - wine_df["pH"].min())/ (wine_df["pH"].max()-wine_df["pH"].min())
#     df2[ "alcohol"] = (wine_df.loc[i, "alcohol"] - wine_df["alcohol"].min())/ (wine_df["alcohol"].max()-wine_df["alcohol"].min())
#     df2["quality"] = (wine_df.loc[i, "quality"] - wine_df["quality"].min())/ (wine_df["quality"].max()-wine_df["quality"].min())

# %%
# # write the normalized data to a new csv file.
# df2.to_csv(r'./normalizedWineData.csv')
# df2.head()

# %%
wine_df2 = pd.read_csv('./normalizedWineData.csv')

# %%
wine_df2 = wine_df2.drop(['Unnamed: 0'], axis=1)

# %%
wine_df2.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        0.612670          0.330381     0.270976        0.149587
# std         0.133453          0.162476     0.194801        0.104794
# min         0.000000          0.000000     0.000000        0.020000
# 25%         0.510000          0.210000     0.090000        0.100000
# 50%         0.600000          0.300000     0.260000        0.120000
# 75%         0.690000          0.410000     0.420000        0.150000
# max         1.000000          1.000000     1.000000        1.000000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467             0.228118              0.204453     0.984040
# std       0.047065             0.163717              0.174137     0.025261
# ...

# %%
# wine_df.describe().to_csv(r'Resources/describe_df.csv')

# %%
plt.figure(figsize=(15,10))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
sns.boxplot(data=wine_df2.drop(columns=['quality']), orient='horizontal', palette='husl')
plt.savefig('./Resources/wine-boxplot3.png')

# %% [markdown]
# ### Observation
#
# The distribution looks must better after data normalization

# %%
sns.set()

wine_df2.hist(figsize=(15,15), color='maroon')
plt.show()
plt.savefig('./Resources/wine-hist2.png')

# %%
plt.rcParams.update({'font.size':16, 'xtick.labelsize':16, 'ytick.labelsize': 16, 'axes.titlesize':24, 'axes.labelsize':16})

fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'fixed acidity', data = wine_df2)
plt.savefig('./wine-barplot-fixedAcidity.png')

fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'volatile acidity', data = wine_df2)
plt.savefig('./wine-barplot-volatileAcidity.png')

fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'citric acid', data = wine_df2)
plt.savefig('./wine-barplot-citricAcid.png')

fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'residual sugar', data = wine_df2)
plt.savefig('./wine-barplot-sugar.png')

fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'chlorides', data = wine_df2)
plt.savefig('./wine-barplot-chlorides.png')

fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'free sulfur dioxide', data = wine_df2)
plt.savefig('./wine-barplot-freeSulferDioxide.png')

fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'total sulfur dioxide', data = wine_df2)
plt.savefig('./wine-barplot-totalSulfurDioxide.png')

fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'density', data = wine_df2)
plt.savefig('./wine-barplot-density.png')

fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'pH', data = wine_df2)
plt.savefig('./wine-barplot-pH.png')

fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'sulphates', data = wine_df2)
plt.savefig('./wine-barplot-sulphates.png')

fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'alcohol', data = wine_df2)
plt.savefig('./wine-barplot-alcohol.png')

# %% [markdown]
# ### Observation
# Citric acid, sulphates and alcohol go up as quality goes up.
#
# Volatile acidity, chlorides,density and pH go down as quality goes up.

# %% [markdown]
# # Correlation

# %%
colormap = plt.cm.viridis
plt.figure(figsize=(15,15))
plt.title('Correlation of Features', y=1.05, size=20)
plt.rcParams.update({'font.size': 16})
sns.heatmap(wine_df2.astype(float).corr(),linewidths=0.1,vmax=1.0, square=True, 
            cmap=sns.diverging_palette(250, 20, n=200),
            linecolor='white', annot=True)
plt.savefig('./Resources/wine-correlation.png')

# %% [markdown]
# ### Observation
# [Citric acid and fixed acidity], [density and fixed acidity] and [free sulfur dioxide and total sulfur dioxide] are somewhat correlated.
#
# It is good because it means the features are relatively independent from each other and all of them can be used for our ML model.
